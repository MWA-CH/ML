# %%
import pandas as pd

# %%
# one dimentional series
mobile = pd.Series(['samsung','iphone','nokia'])
mobile
# Out:
# 0    samsung
# 1     iphone
# 2      nokia
# dtype: object

# %%
# one dimentional series
bag = pd.Series(['pen','paper','notebook'])
bag
# Out:
# 0         pen
# 1       paper
# 2    notebook
# dtype: object

# %%
# two dimentional Data : DataFrame
dataframe = pd.DataFrame({"Electronics":mobile,"item":bag})
dataframe
# Out:
#   Electronics      item
# 0     samsung       pen
# 1      iphone     paper
# 2       nokia  notebook

# %%
# How to Import Data
# Most common Files Format CSV Comma Seperated Values
phone_csv = pd.read_csv("heart.csv.xls")

# %%
phone_csv
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
phone_csv.to_csv("Modified_data", index=False)

# %%
pcsv = pd.read_csv("Modified_data")

# %%
pcsv
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %% [markdown]
# # How to Describe Data

# %%
#Attributes
pcsv.dtypes
#Functions()
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
pcsv.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
columns = pcsv.columns

# %%
columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
pcsv.index
# Out:
# RangeIndex(start=0, stop=1025, step=1)

# %%
pcsv.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
pcsv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
pcsv.mean()
# Out:
# age          54.434146
# sex           0.695610
# cp            0.942439
# trestbps    131.611707
# chol        246.000000
# fbs           0.149268
# restecg       0.529756
# thalach     149.114146
# exang         0.336585
# oldpeak       1.071512
# slope         1.385366
# ca            0.754146
# thal          2.323902
# target        0.513171
# dtype: float64

# %%
pcsv['age'].sum()
# Out:
# 55795

# %% [markdown]
# # Data Selection

# %%
pcsv.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
pcsv.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %%
pcsv.tail(6)
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1019      2   0     2       1
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# #  index(.loc) or Location(.iloc)

# %%
birds = pd.Series(['crow','pigion','parrot','sparrow','eagle'], index=[0,9,3,5,8])

# %%
birds
# Out:
# 0       crow
# 9     pigion
# 3     parrot
# 5    sparrow
# 8      eagle
# dtype: object

# %%
birds.loc[3]
# Out:
# 'parrot'

# %%
birds.iloc[2]
# Out:
# 'parrot'

# %%
pcsv.loc[1020]
# Out:
# age          59.0
# sex           1.0
# cp            1.0
# trestbps    140.0
# chol        221.0
# fbs           0.0
# restecg       1.0
# thalach     164.0
# exang         1.0
# oldpeak       0.0
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 1020, dtype: float64

# %%
pcsv.iloc[1020]
# Out:
# age          59.0
# sex           1.0
# cp            1.0
# trestbps    140.0
# chol        221.0
# fbs           0.0
# restecg       1.0
# thalach     164.0
# exang         1.0
# oldpeak       0.0
# slope         2.0
# ca            0.0
# thal          2.0
# target        1.0
# Name: 1020, dtype: float64

# %%
pcsv.iloc[:3]
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0

# %%
pcsv['age']
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
pcsv.age
# Out:
# 0       52
# 1       53
# 2       70
# 3       61
# 4       62
#         ..
# 1020    59
# 1021    60
# 1022    47
# 1023    50
# 1024    54
# Name: age, Length: 1025, dtype: int64

# %%
pcsv[pcsv['age']<= 50]
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 8      46    1   0       120   249    0        0      144      0      0.8
# 11     43    0   0       132   341    1        0      136      1      3.0
# 12     34    0   1       118   210    0        1      192      0      0.7
# 15     34    0   1       118   210    0        1      192      0      0.7
# 18     50    0   1       120   244    0        1      162      0      1.1
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1014   44    0   2       108   141    0        1      175      0      0.6
# 1018   41    1   0       110   172    0        0      158      0      0.0
# 1019   47    1   0       112   204    0        1      143      0      0.1
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
#
#       slope  ca  thal  target
# 8         2   0     3       0
# ...

# %% [markdown]
# # Data Selection 2

# %%
pd.crosstab(pcsv['age'],pcsv['sex'])
# Out:
# sex   0   1
# age
# 29    0   4
# 34    3   3
# 35    4  11
# 37    3   3
# 38    0  12
# 39    7   7
# 40    0  11
# 41   12  20
# 42    6  20
# 43    7  19
# 44    6  30
# 45   10  15
# 46    9  14
# 47    0  18
# 48    3  20
# 49    6  11
# 50    9  12
# 51   12  27
# 52    3  40
# 53    9  17
# 54   15  38
# 55   15  15
# 56   10  29
# 57   12  45
# 58   21  47
# 59    3  43
# 60   13  24
# 61    8  23
# 62   24  13
# 63   17  15
# 64    9  25
# 65   13  14
# 66   11  14
# 67    9  22
# 68    3   9
# 69    3   6
# 70    0  14
# 71   11   0
# 74    3   0
# 76    3   0
# 77    0   3

# %%
# more then two column compare command groupby
pcsv.groupby('age').mean()
# Out:
#           sex        cp    trestbps        chol       fbs   restecg  \
# age
# 29   1.000000  1.000000  130.000000  204.000000  0.000000  0.000000
# 34   0.500000  2.000000  118.000000  196.000000  0.000000  0.500000
# 35   0.733333  0.266667  126.533333  209.200000  0.000000  0.800000
# 37   0.500000  2.000000  125.000000  232.500000  0.000000  1.000000
# 38   1.000000  2.333333  132.000000  193.666667  0.000000  1.000000
# 39   0.500000  1.428571  123.285714  236.857143  0.000000  0.785714
# 40   1.000000  0.818182  133.454545  196.090909  0.000000  0.636364
# 41   0.625000  1.187500  119.531250  218.156250  0.000000  0.625000
# 42   0.769231  1.230769  127.461538  246.807692  0.115385  0.769231
# 43   0.730769  0.461538  126.346154  256.923077  0.269231  0.576923
# 44   0.833333  1.166667  120.666667  220.000000  0.000000  0.666667
# 45   0.600000  0.760000  122.680000  246.840000  0.000000  0.240000
# 46   0.608696  0.782609  128.173913  234.608696  0.130435  0.565217
# ...

# %%
# How to plot data
pcsv['age'].plot()
# Out:
# <Axes: >

# %%
pcsv['age'].hist()
# Out:
# <Axes: >

# %%
pcsv.dtypes
# Out:
# age           int64
# sex           int64
# cp            int64
# trestbps      int64
# chol          int64
# fbs           int64
# restecg       int64
# thalach       int64
# exang         int64
# oldpeak     float64
# slope         int64
# ca            int64
# thal          int64
# target        int64
# dtype: object

# %%
#pcsv['stringcolumn name'] = pcsv['stringColumn'].str.replace('[\$\,\.]','')astype(int) string column ko int my
#convert and clean data remove dollar sign and .

# %% [markdown]
# # Changeing Data

# %%
data = pd.Series(['White','Brown','Black','Blue','Green','Yellow'])

# %%
data.str.lower()
# Out:
# 0     white
# 1     brown
# 2     black
# 3      blue
# 4     green
# 5    yellow
# dtype: object

# %%
pdmv = pd.read_csv('Phone_data_missing_values.csv')

# %%
pdmv['Colour'].str.lower()
# Out:
# 0     white
# 1       red
# 2       NaN
# 3     black
# 4     white
# 5       NaN
# 6      blue
# 7    purple
# 8     white
# 9     white
# Name: Colour, dtype: object

# %%
pdmv
# Out:
#         Make  Colour  Memory(kb)  Sim Cards       Price
# 0      Nokia   White    150043.0          4    $400.00
# 1    Samsung     Red     87899.0          4    $500.00
# 2      Nokia     NaN         NaN          3         NaN
# 3     Iphone   Black    134721.0          2  $1,000.00
# 4  Motorolla   White    213095.0          4    $350.00
# 5      Nokia     NaN         NaN          4         NaN
# 6    Samsung    Blue     45687.0          3    $750.00
# 7    Samsung  Purple         NaN          3    $625.00
# 8        NaN   White     60000.0          4    $700.00
# 9  Motorolla   White     31600.0          4    $970.00

# %%
pdmv['Memory(kb)'].mean()
# Out:
# 103292.14285714286

# %%
pdmv['Memory(kb)'].fillna(pdmv['Memory(kb)'].mean(),inplace=True)

# %%
pdmv
# Out:
#         Make  Colour     Memory(kb)  Sim Cards       Price
# 0      Nokia   White  150043.000000          4    $400.00
# 1    Samsung     Red   87899.000000          4    $500.00
# 2      Nokia     NaN  103292.142857          3         NaN
# 3     Iphone   Black  134721.000000          2  $1,000.00
# 4  Motorolla   White  213095.000000          4    $350.00
# 5      Nokia     NaN  103292.142857          4         NaN
# 6    Samsung    Blue   45687.000000          3    $750.00
# 7    Samsung  Purple  103292.142857          3    $625.00
# 8        NaN   White   60000.000000          4    $700.00
# 9  Motorolla   White   31600.000000          4    $970.00

# %%
pdmv.dropna()
# Out:
#         Make  Colour     Memory(kb)  Sim Cards       Price
# 0      Nokia   White  150043.000000          4    $400.00
# 1    Samsung     Red   87899.000000          4    $500.00
# 3     Iphone   Black  134721.000000          2  $1,000.00
# 4  Motorolla   White  213095.000000          4    $350.00
# 6    Samsung    Blue   45687.000000          3    $750.00
# 7    Samsung  Purple  103292.142857          3    $625.00
# 9  Motorolla   White   31600.000000          4    $970.00

# %%
pdmv
# Out:
#         Make  Colour     Memory(kb)  Sim Cards       Price
# 0      Nokia   White  150043.000000          4    $400.00
# 1    Samsung     Red   87899.000000          4    $500.00
# 2      Nokia     NaN  103292.142857          3         NaN
# 3     Iphone   Black  134721.000000          2  $1,000.00
# 4  Motorolla   White  213095.000000          4    $350.00
# 5      Nokia     NaN  103292.142857          4         NaN
# 6    Samsung    Blue   45687.000000          3    $750.00
# 7    Samsung  Purple  103292.142857          3    $625.00
# 8        NaN   White   60000.000000          4    $700.00
# 9  Motorolla   White   31600.000000          4    $970.00

# %%
pdmv.dropna(inplace=True)

# %%
pdmv
# Out:
#         Make  Colour     Memory(kb)  Sim Cards       Price
# 0      Nokia   White  150043.000000          4    $400.00
# 1    Samsung     Red   87899.000000          4    $500.00
# 3     Iphone   Black  134721.000000          2  $1,000.00
# 4  Motorolla   White  213095.000000          4    $350.00
# 6    Samsung    Blue   45687.000000          3    $750.00
# 7    Samsung  Purple  103292.142857          3    $625.00
# 9  Motorolla   White   31600.000000          4    $970.00

# %%
pdmv = pdmv.dropna()

# %%
pdmv
# Out:
#         Make  Colour     Memory(kb)  Sim Cards       Price
# 0      Nokia   White  150043.000000          4    $400.00
# 1    Samsung     Red   87899.000000          4    $500.00
# 3     Iphone   Black  134721.000000          2  $1,000.00
# 4  Motorolla   White  213095.000000          4    $350.00
# 6    Samsung    Blue   45687.000000          3    $750.00
# 7    Samsung  Purple  103292.142857          3    $625.00
# 9  Motorolla   White   31600.000000          4    $970.00

# %%
pdmv = pd.read_csv('Phone_data_missing_values.csv')

# %%
pdmv
# Out:
#         Make  Colour  Memory(kb)  Sim Cards       Price
# 0      Nokia   White    150043.0          4    $400.00
# 1    Samsung     Red     87899.0          4    $500.00
# 2      Nokia     NaN         NaN          3         NaN
# 3     Iphone   Black    134721.0          2  $1,000.00
# 4  Motorolla   White    213095.0          4    $350.00
# 5      Nokia     NaN         NaN          4         NaN
# 6    Samsung    Blue     45687.0          3    $750.00
# 7    Samsung  Purple         NaN          3    $625.00
# 8        NaN   White     60000.0          4    $700.00
# 9  Motorolla   White     31600.0          4    $970.00

# %%
pdmv = pdmv.dropna()

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price
# 0      Nokia  White    150043.0          4    $400.00
# 1    Samsung    Red     87899.0          4    $500.00
# 3     Iphone  Black    134721.0          2  $1,000.00
# 4  Motorolla  White    213095.0          4    $350.00
# 6    Samsung   Blue     45687.0          3    $750.00
# 9  Motorolla  White     31600.0          4    $970.00

# %%
pdmv.to_csv('Cleaned_Data.csv')

# %% [markdown]
# # Add Remove and Change Columns

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price
# 0      Nokia  White    150043.0          4    $400.00
# 1    Samsung    Red     87899.0          4    $500.00
# 3     Iphone  Black    134721.0          2  $1,000.00
# 4  Motorolla  White    213095.0          4    $350.00
# 6    Samsung   Blue     45687.0          3    $750.00
# 9  Motorolla  White     31600.0          4    $970.00

# %%
battries = pd.Series([2,4,5,3,7])
pdmv["battries"] = battries
# Out:
# /var/folders/86/gcq2cs692_7g0dzj7fg49jfw0000gp/T/ipykernel_34001/1230921839.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdmv["battries"] = battries

# %%
battries = pd.Series([2,4,5,3,7])
pdmv.insert(5,"Battries",battries)

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price  Battries  Batery  \
# 0      Nokia  White    150043.0          4    $400.00        2.0     2.0
# 1    Samsung    Red     87899.0          4    $500.00        4.0     4.0
# 3     Iphone  Black    134721.0          2  $1,000.00        3.0     3.0
# 4  Motorolla  White    213095.0          4    $350.00        7.0     5.0
# 6    Samsung   Blue     45687.0          3    $750.00        NaN     NaN
# 9  Motorolla  White     31600.0          4    $970.00        NaN     NaN
#
#    batery  battery  battries
# 0     2.0      2.0       2.0
# 1     4.0      4.0       4.0
# 3     3.0      3.0       3.0
# 4     5.0      5.0       7.0
# 6     NaN      NaN       NaN
# 9     NaN      NaN       NaN

# %%
pdmv["Battries"].fillna(5,inplace=True)
# Out:
# /var/folders/86/gcq2cs692_7g0dzj7fg49jfw0000gp/T/ipykernel_34001/3833669173.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdmv["Battries"].fillna(5,inplace=True)

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price  Battries  Batery  \
# 0      Nokia  White    150043.0          4    $400.00        2.0     2.0
# 1    Samsung    Red     87899.0          4    $500.00        4.0     4.0
# 3     Iphone  Black    134721.0          2  $1,000.00        3.0     3.0
# 4  Motorolla  White    213095.0          4    $350.00        7.0     5.0
# 6    Samsung   Blue     45687.0          3    $750.00        5.0     NaN
# 9  Motorolla  White     31600.0          4    $970.00        5.0     NaN
#
#    batery  battery  battries
# 0     2.0      2.0       2.0
# 1     4.0      4.0       4.0
# 3     3.0      3.0       3.0
# 4     5.0      5.0       7.0
# 6     NaN      NaN       NaN
# 9     NaN      NaN       NaN

# %%
ringtones = [3,4,2,5,6,7]
pdmv["Ringtones"] = ringtones
# Out:
# /var/folders/86/gcq2cs692_7g0dzj7fg49jfw0000gp/T/ipykernel_34001/3683910882.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdmv["Ringtones"] = ringtones

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price  Battries  Batery  \
# 0      Nokia  White    150043.0          4    $400.00        2.0     2.0
# 1    Samsung    Red     87899.0          4    $500.00        4.0     4.0
# 3     Iphone  Black    134721.0          2  $1,000.00        3.0     3.0
# 4  Motorolla  White    213095.0          4    $350.00        7.0     5.0
# 6    Samsung   Blue     45687.0          3    $750.00        5.0     NaN
# 9  Motorolla  White     31600.0          4    $970.00        5.0     NaN
#
#    batery  battery  battries  Ringtones
# 0     2.0      2.0       2.0          3
# 1     4.0      4.0       4.0          4
# 3     3.0      3.0       3.0          2
# 4     5.0      5.0       7.0          5
# 6     NaN      NaN       NaN          6
# 9     NaN      NaN       NaN          7

# %%
pdmv["Product"] = pdmv["Battries"] * pdmv["Ringtones"]
# Out:
# /var/folders/86/gcq2cs692_7g0dzj7fg49jfw0000gp/T/ipykernel_34001/3542306529.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pdmv["Product"] = pdmv["Battries"] * pdmv["Ringtones"]

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price  Battries  Batery  \
# 0      Nokia  White    150043.0          4    $400.00        2.0     2.0
# 1    Samsung    Red     87899.0          4    $500.00        4.0     4.0
# 3     Iphone  Black    134721.0          2  $1,000.00        3.0     3.0
# 4  Motorolla  White    213095.0          4    $350.00        7.0     5.0
# 6    Samsung   Blue     45687.0          3    $750.00        5.0     NaN
# 9  Motorolla  White     31600.0          4    $970.00        5.0     NaN
#
#    batery  battery  battries  Ringtones  Product
# 0     2.0      2.0       2.0          3      6.0
# 1     4.0      4.0       4.0          4     16.0
# 3     3.0      3.0       3.0          2      6.0
# 4     5.0      5.0       7.0          5     35.0
# 6     NaN      NaN       NaN          6     30.0
# 9     NaN      NaN       NaN          7     35.0

# %%
pdmv = pdmv.drop('battery',axis=1)

# %%
pdmv
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price  Battries  Ringtones  \
# 0      Nokia  White    150043.0          4    $400.00        2.0          3
# 1    Samsung    Red     87899.0          4    $500.00        4.0          4
# 3     Iphone  Black    134721.0          2  $1,000.00        3.0          2
# 4  Motorolla  White    213095.0          4    $350.00        7.0          5
# 6    Samsung   Blue     45687.0          3    $750.00        5.0          6
# 9  Motorolla  White     31600.0          4    $970.00        5.0          7
#
#    Product
# 0      6.0
# 1     16.0
# 3      6.0
# 4     35.0
# 6     30.0
# 9     35.0

# %% [markdown]
# # Manipulating Data

# %%
pdmv.sample(frac=1) #frac = 0.25 means 25% only or 0.50 means half 1 mean 100% data shuffle
# Out:
#         Make Colour  Memory(kb)  Sim Cards       Price  Battries  Ringtones  \
# 3     Iphone  Black    134721.0          2  $1,000.00        3.0          2
# 0      Nokia  White    150043.0          4    $400.00        2.0          3
# 9  Motorolla  White     31600.0          4    $970.00        5.0          7
# 1    Samsung    Red     87899.0          4    $500.00        4.0          4
# 4  Motorolla  White    213095.0          4    $350.00        7.0          5
# 6    Samsung   Blue     45687.0          3    $750.00        5.0          6
#
#    Product
# 3      6.0
# 0      6.0
# 9     35.0
# 1     16.0
# 4     35.0
# 6     30.0

# %%
pdmv.reset_index(drop=True,inplace=True)

# %%
pdmv
# Out:
#         Make  Colour  Memory(kb)  Sim Cards       Price
# 0      Nokia   White    150043.0          4    $400.00
# 1    Samsung     Red     87899.0          4    $500.00
# 2      Nokia     NaN         NaN          3         NaN
# 3     Iphone   Black    134721.0          2  $1,000.00
# 4  Motorolla   White    213095.0          4    $350.00
# 5      Nokia     NaN         NaN          4         NaN
# 6    Samsung    Blue     45687.0          3    $750.00
# 7    Samsung  Purple         NaN          3    $625.00
# 8        NaN   White     60000.0          4    $700.00
# 9  Motorolla   White     31600.0          4    $970.00

# %%
monthly_report = pd.read_csv("MRRA23.csv")

# %%
monthly_report
# Out:
#    Unnamed: 0 Monthly Performance Review for the month of May 2023 Unnamed: 2  \
# 0         NaN                                                NaN          NaN
# 1        S.NO                                        Center Name         Enq
# 2         NaN                                                NaN        Total
# 3           1                             Garden Center, Karachi         -
# 4           2                        N.Nazimabad Center, Karachi         -
# 5           3                   Shahrah-e-Faisal Center, Karachi         630
# 6           4                       Railway Road Center, Sialkot         -
# 7           5                         Queens Road Center, Sukkur         -
# 8           6                        Latifabad Center, Hyderabad         -
# 9           7                    Gulshan-e-Iqbal Center, Karachi         -
# 10          8                            Defence Center, Karachi         -
# ...
